# %%
import cv2
import numpy as np

# Read input image
img = cv2.imread('floor.jpg')

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply edge detection
edges = cv2.Canny(gray, 50, 150)

# Apply Hough transform to detect lines
lines = cv2.HoughLines(edges, 1, np.pi/180, 200)

# Find the lines corresponding to the floor and walls of the room
floor_lines = []
wall_lines = []
for line in lines:
    rho, theta = line[0]
    if abs(theta) < np.pi/4:
        if rho > img.shape[0]/2:
            floor_lines.append(line)
        else:
            wall_lines.append(line)
    else:
        if rho > img.shape[1]/2:
            wall_lines.append(line)
        else:
            wall_lines.append(line)

# Find the blue landmark
blue_landmark = None
for line in wall_lines:
    rho, theta = line[0]
    if abs(theta) < np.pi/4:
        x = rho/np.cos(theta)
        y = 0
        if 0 <= x < img.shape[1]:
            blue_landmark = (x, y)
            break

# Calculate homography matrix
src_pts = np.float32([[x, y] for x, y in floor_lines[:,0,:2]])
dst_pts = np.float32([[blue_landmark[0], blue_landmark[1]], [0, 0], [0, img.shape[0]], [img.shape[1], img.shape[0]], [img.shape[1], 0]])
H, _ = cv2.findHomography(src_pts, dst_pts)

# Find the red landmark
red_landmark = None
for line in wall_lines:
    rho, theta = line[0]
    if abs(theta) < np.pi/4:
        x = rho/np.cos(theta)
        y = (rho - H[1,0]*x - H[1,2])/H[1,1]
        if 0 <= x < img.shape[1] and 0 <= y < img.shape[0]:
            red_landmark = (x, y)
            break

# Plot the 2D representation of the room
map_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
for line in wall_lines:
    rho, theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 44
#      41             break
#      43 # Calculate homography matrix
# ---> 44 src_pts = np.float32([[x, y] for x, y in floor_lines[:,0,:2]])
#      45 dst_pts = np.float32([[blue_landmark[0], blue_landmark[1]], [0, 0], [0, img.shape[0]], [img.shape[1], img.shape[0]], [img.shape[1], 0]])
#      46 H, _ = cv2.findHomography(src_pts, dst_pts)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# !sudo apt-get update && sudo apt-get install -y libgl1-mesa-glx
# Out:
# Get:1 https://packages.microsoft.com/repos/microsoft-ubuntu-focal-prod focal InRelease [3611 B]
# Get:2 http://archive.ubuntu.com/ubuntu focal InRelease [265 kB]
# Get:3 https://dl.yarnpkg.com/debian stable InRelease [17.1 kB]
# Get:4 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable InRelease [3960 B]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:8 https://packages.microsoft.com/repos/microsoft-ubuntu-focal-prod focal/main all Packages [2460 B]
# Get:9 https://packages.microsoft.com/repos/microsoft-ubuntu-focal-prod focal/main amd64 Packages [199 kB]
# Get:11 https://dl.yarnpkg.com/debian stable/main amd64 Packages [11.1 kB]
# Get:12 https://dl.yarnpkg.com/debian stable/main all Packages [11.1 kB]
# Get:13 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable/main amd64 Packages [2120 B]
# ...

# %%
# !sudo apt-get install libgl1-mesa-glx
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1-mesa-glx is already the newest version (21.2.6-0ubuntu0.1~20.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.
